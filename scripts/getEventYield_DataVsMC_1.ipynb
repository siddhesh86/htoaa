# %%
import os, sys
import numpy as np
from collections import OrderedDict as OD
#import uproot3 as uproot
#import uproot3 
import uproot as uproot
import hist
import matplotlib.pyplot as plt
import mplhep as hep
import json

sys.path.insert(1, '../') # to import file from other directory (../ in this case)

from htoaa_CommonTools import(
    getTH1BinContent
)

#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20230831_SelPNetMDXbbNSV/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20230831_SelPNetMDXbbNSV/2018/plots'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20230914_PNetMDXbbNSV_wSFPNetMDXbb_1/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20230914_PNetMDXbbNSV_wSFPNetMDXbb_1/2018/plots'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20230921_SFPNetMDXbbvsQCD/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20230921_SFPNetMDXbbvsQCD/2018/plots'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20240806_VBFjj_Sig/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20240806_VBFjj_Sig/2018/plots'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20250227_gg0l_DataMC_1/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250227_gg0l_DataMC_1/2018/plots'
sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_gg0l_DataMCPlots_NoSyst/2018/analyze_htoaa_stage1.root'
sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_gg0l_DataMCPlots_NoSyst/2018/plots_tmp'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_Vjj_DataMCPlots_NoSyst/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_Vjj_DataMCPlots_NoSyst/2018/plots'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_Zvv_DataMCPlots_NoSyst/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_Zvv_DataMCPlots_NoSyst/2018/plots'
#sIpFile = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_tt0l_DataMCPlots_NoSyst/2018/analyze_htoaa_stage1.root'
#sOpDir  = '/eos/cms/store/user/ssawant/htoaa/analysis/20250507_tt0l_DataMCPlots_NoSyst/2018/plots'

CAT = 'gg0lIncl' # 'gg0l', 'VBFjj', 'Wlv', 'Zll', 'Zvv',  'Vjj'. 'ZvvIncl','ZvvLo', 'ZvvHi', 'gg0lIncl', 'gg0lLo', 'gg0lHi', 'tt0l', 'VBFjj'
# 'tt0l_ge1NonHFatJet_0BExtra', 'tt0l_ge1NonHFatJet_1BExtra', 'tt0l_ge1NonHFatJet_ge2BExtra', 'tt0l_0NonHFatJet_ge2B'

sSubcategory = '%s_' % (CAT) if CAT in ['ZvvIncl', 'ZvvLo', 'ZvvHi', 'gg0lIncl', 'gg0lLo', 'gg0lHi', 'tt0l_ge1NonHFatJet_0BExtra', 'VBFjj'] else '' # 'ZvvIncl' # 'gg0l', 'VBFjj', 'Wlv', 'Zll', 'Zvv',  'Vjj'
#selectionTags = ['%sSBWP80to40' % (sSubcategory)]
#selectionTags = ['tt0l_ge1NonHFatJet_0BExtra_SRWP80', 'tt0l_ge1NonHFatJet_1BExtra_SRWP80', 'tt0l_ge1NonHFatJet_ge2BExtra_SRWP80', 'tt0l_0NonHFatJet_ge2B_SRWP80']
#selectionTags = [ 'tt0l_ge1NonHFatJet_1BExtra_Hi_SRWP80', 'tt0l_ge1NonHFatJet_1BExtra_Med_SRWP80', 'tt0l_ge1NonHFatJet_1BExtra_Lo_SRWP80' ]
#selectionTags = ['gg0lIncl_SRWP40', 'VBFLoose_SRWP40', 'VBFTight_SRWP40', 'VBFLoose_SRWP80', 'VBFTight_SRWP80']
#selectionTags = ['gg0lIncl_SRWP40']
#selectionTags = ['%s_Xto4bv2_SRWP40' % (CAT),  '%s_Xto4bv2_SBWP40' % (CAT),]
selectionTags = ['%s_Xto4bv2_SRWP40' % (CAT)] #['%s_Xto4bv2_SRWP40' % (CAT),  '%s_Xto4bv2_SBWP40' % (CAT),]


sOpDir = '%s/%s' % (sOpDir, CAT)
if not os.path.exists(sOpDir):
    os.makedirs(sOpDir)
    
fIpFile = uproot.open(sIpFile)

# %%
fIpFile['evt'].keys()
# Out:
# ['JetHT_Run2018A;1',
#  'JetHT_Run2018A/hEventWeight_PU_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PS_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_Presel;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_Presel;1',
#  'JetHT_Run2018A/hCutFlow_Presel_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_Presel_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_Presel_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_Presel_noweight;1',
#  'JetHT_Run2018A/hMET_pT_Presel_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_Presel_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_Presel_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SRWP40;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SRWP40_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SBWP60_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SBplusSRWP60;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SBplusSRWP60_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SRWP80;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lIncl_Xto4bv2_SRWP80_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lIncl_Xto4bv2_SBWP80;1',
#  'JetHT_Run2018A/hCutFlow_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lIncl_Xto4bv2_SBWP80_noweight;1',
# ...
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lLo_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lLo_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lLo_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lLo_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lLo_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lLo_Xto4bv2_SBWP40;1',
#  'JetHT_Run2018A/hCutFlow_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lLo_Xto4bv2_SBWP40_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lLo_Xto4bv2_SBplusSRWP40;1',
#  'JetHT_Run2018A/hCutFlow_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lLo_Xto4bv2_SBplusSRWP40_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_FSRDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfNom_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPdfDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_Nom_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_RenormDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDScale_FactorizationDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFNom_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_QCDPDFDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagNom_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUp_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDown_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpuncorrelated_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDownuncorrelated_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagUpcorrelated_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hEventWeight_Ak4BtagDowncorrelated_gg0lLo_Xto4bv2_SRWP60;1',
#  'JetHT_Run2018A/hCutFlow_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hCutFlowWeighted_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA_Hto4b_avg_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massAa_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massAa_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massAa_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34a_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34a_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34a_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34b_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34d_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_vs_massA34ad_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_vs_massA34d_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massH_v2b_vs_massA34d_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hPV_npvsGood_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPt_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetEta_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPhi_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMass_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMSoftDrop_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massH_Hto4b_avg_v0123_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetParticleNet_massA_Hto4b_avg_v013_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hnleadingNonHto4bFatJet_WZvsQCD_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hMET_pT_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hPuppiMET_pT_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_vs_QCD_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v1_Haa4b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa4b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa4b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa4b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2a_Haa34b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2b_Haa34b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_X4b_v2ab_Haa34b_score_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetMassH_v2b_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAa_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAa_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAb_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_34massAd_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA1_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massA2_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_massAA_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hLeadingFatJetPNet_dMassAA_relH_gg0lLo_Xto4bv2_SRWP60_noweight;1',
#  'JetHT_Run2018A/hEventWeight_PU_gg0lLo_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUUp_gg0lLo_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PUDown_gg0lLo_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_gg0lLo_Xto4bv2_SBWP60;1',
#  'JetHT_Run2018A/hEventWeight_PS_ISRUp_gg0lLo_Xto4bv2_SBWP60;1',
#  ...]

# %%
'''
for histName_ in fIpFile['evt/Data'].keys():
    if 'hCutFlowWeighted' in histName_:
        print(f"{histName_}")
        if 'sel_leadingFatJetParticleNetMD_XbbvsQCD' in histName_:
            print(f"{histName_} that is wanted\n\n")
'''
# Out:
# '\nfor histName_ in fIpFile[\'evt/Data\'].keys():\n    if \'hCutFlowWeighted\' in histName_:\n        print(f"{histName_}")\n        if \'sel_leadingFatJetParticleNetMD_XbbvsQCD\' in histName_:\n            print(f"{histName_} that is wanted\n\n")\n'

# %%
#sData = "Data"
ExpData_dict = {} #{
    #'Data': ['JetHT_Run2018A', 'JetHT_Run2018B', 'JetHT_Run2018C', 'JetHT_Run2018D']
    #'Data': ['MET_Run2018A', 'MET_Run2018B', 'MET_Run2018C', 'MET_Run2018D'] if CAT in ['ZvvIncl'] else ['JetHT_Run2018A', 'JetHT_Run2018B', 'JetHT_Run2018C', 'JetHT_Run2018D'] # 'gg0l', 'VBFjj', 'Wlv', 'Zll', 'Zvv',  'Vjj'
    #'Data ABCD': ['SingleMuon_Run2018A', 'SingleMuon_Run2018B', 'SingleMuon_Run2018C', 'SingleMuon_Run2018D'],
#}
#ExpData_dict['Data'] = []
ExpData_dict['Data'] = ['JetHT_Run2018A', 'JetHT_Run2018B', 'JetHT_Run2018C', 'JetHT_Run2018D']
if 'Zvv' in CAT:
    ExpData_dict['Data'] = ['MET_Run2018A', 'MET_Run2018B', 'MET_Run2018C', 'MET_Run2018D']

#MCBkg_list = ['QCD_bEnrich', 'QCD_bGen', 'QCD_Incl', 'TTJets_NLO', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD',  'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = ['QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']

#MCBkg_list = ['QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg', 'WJetsToQQ_HT', 'ZJetsToQQ_HT']
#MCBkg_list = [
#    'QCD_0bCat', 'QCD_1bCat', 'QCD_2bCat', 'QCD_3bCat', 'QCD_4bCat', 'QCD_5bAndMoreCat',  
#    'TTToHadronic_powheg', 'TTToSemiLeptonic_powheg', 'TTTo2L2Nu_powheg', "SingleTop", 
#    'ZJetsToQQ_HT', "ZJetsToNuNuQ_HT",
#    "DYJets_M-50_Incl_NLO", #"DYJets_M-10to50_Incl_NLO", "DYJets_M-50_Incl_NLO", 
#    'WJetsToQQ_HT', 
#    'WJetsToLNu_HT_LO', #'WJetsToLNu_Incl_NLO', 
#    'ZZ','WZ','WW', 'ZZZ','WZZ','WWZ','WWW',
#    'GluGluHToBB_Pt-200ToInf', 
#    #'VBFHToBB_powheg', 'VBFHToBB_dipoleRecoilOn', 
#    #'VBFWH_HToBB_WToLNu_dipoleRecoilOn', 
#    'WH_HToBB_WToQQ', 'WH_HToBB_WToLNu', 
#    'ZH_HToBB', #'ggZH_HToBB', 
#    'ttH', 
#]
MCBkg_list = [
    "QCD_bEnr", "QCD_BGen", "QCD_Incl", 
    "TT0l", "TT1l", "TT2l", 
    "STop_t", "STbar_t", "ST_s_0l", "ST_s_1l", "STop_tW_Incl", "STbar_tW_Incl", "STop_tW_12l", "STbar_tW_12l", 
    #"ttZ", "ttW", "tZq", 
    "Zqq", "Zvv", "Zll", "Wqq", "Wlv", 
    "ZZ", "WZ", "WW", #"ZZZ", "WZZ", "WWZ", "WWW", 
    #"ggH", #"VBFH", "VBFH_dipoleRecoilOn", "VBFWH_dipoleRecoilOn", 
    #"WHbbqq", "WHbblv", 
    #"ZH", #"ggZH", 
    #"ttH", #"", "", "", 
    #"", "", "", "", "", "",     
]
#MCBkg_list = []
'''
MCBkg_dict = {
    'QCD': ["QCD_bEnr", "QCD_BGen", "QCD_Incl"],
    r't$\bar{t}$+X': ["TT0l", "TT1l", "TT2l"],
    'Single top': ["STop_t", "STbar_t", "ST_s_0l", "ST_s_1l", "STop_tW_Incl", "STbar_tW_Incl", "STop_tW_12l", "STbar_tW_12l"],
    'V+X': ["Zqq", "Zvv", "Zll", "Wqq", "Wlv"],
    'Diboson': ["ZZ", "WZ", "WW"],
    #'': [],
}
'''
MCSig_list = [
    #'SUSY_GluGluH_01J_HToAATo4B_M-15_HPtAbv150', 
    #'SUSY_GluGluH_01J_HToAATo4B_M-30_HPtAbv150', 
    #'SUSY_GluGluH_01J_HToAATo4B_M-55_HPtAbv150', 
    #'SUSY_ZH_ZToAll_HToAATo4B_M-15_HPtAbv150',
    #'SUSY_ZH_ZToAll_HToAATo4B_M-30_HPtAbv150',
    #'SUSY_ZH_ZToAll_HToAATo4B_M-55_HPtAbv150',
    'ggHtoaato4b_mA_15',    
    #'ggHtoaato4b_mA_20',
    #'VBFHtoaato4b_mA_20',
    #'WHtoaato4b_mA_20',
    #'ZHtoaato4b_mA_20',
    #'ttHtoaato4b_mA_20',
    #
    'ggHtoaato4b_mA_30',
    #'VBFHtoaato4b_mA_30',
    #'WHtoaato4b_mA_30',
    #'ZHtoaato4b_mA_30',
    #'ttHtoaato4b_mA_30',
]
sLableSig  = [
    #'GluGluHToAATo4B_M-15', 
    #'GluGluHToAATo4B_M-30', 
    #'GluGluHToAATo4B_M-55',
    #'ZHToAATo4B_M-15', 
    #'ZHToAATo4B_M-30', 
    #'ZHToAATo4B_M-55',
    'ggHtoaato4b_mA_15',
    #'ggHtoaato4b_mA_20',
    #'VBFHtoaato4b_mA_20',
    #'WHtoaato4b_mA_20',
    #'ZHtoaato4b_mA_20',
    #'ttHtoaato4b_mA_20',
    #
    'ggHtoaato4b_mA_30',
    #'VBFHtoaato4b_mA_30',
    #'WHtoaato4b_mA_30',
    #'ZHtoaato4b_mA_30',
    #'ttHtoaato4b_mA_30',
]

systematics_list = ['Nom'] # ['central']
systematics_forData = 'noweight'
xValueForEventYield = 4
#selectionTags = ['sel_HLT_AK8PFJet330_TrimMass30_PFAK8BoostedDoubleB_np4', 'sel_leadingFatJetMSoftDrop', 'sel_leadingFatJetParticleNetMD_bbvsQCD']
#selectionTags = ['sel_HLT_AK8PFJet330_TrimMass30_PFAK8BoostedDoubleB_np4', 'sel_leadingFatJetMSoftDrop', 'sel_leadingFatJetParticleNetMD_XbbvsQCD']
#selectionTags = ['sel_HLT_AK8PFJet330_TrimMass30_PFAK8BoostedDoubleB_np4', 'sel_2018HEM1516Issue', 'sel_leadingFatJetMSoftDrop', 'sel_leadingFatJetParticleNetMD_XbbvsQCD', 'SR'] #['SR', 'sel_leadingFatJetMSoftDrop', ]
#selectionTags = ['sel_leadingMuonPt', 'sel_leadingMuonEta', 'sel_L1_SingleMu22', 'sel_HLT_IsoMu24', 'sel_dR_Muon_FatJet', 'sel_leadingFatJetEta', 'sel_JetID', 'sel_leadingFatJetZHbb_Xbb_avg', 'SR', 'SR_Trg_Combo_AK4AK8Jet_HT']
#sSubcategory = '%s_' % (CAT) if CAT in ['ZvvIncl', 'ZvvLo', 'ZvvHi', 'gg0lIncl', 'gg0lLo', 'gg0lHi'] else '' # 'ZvvIncl' # 'gg0l', 'VBFjj', 'Wlv', 'Zll', 'Zvv',  'Vjj'
#selectionTags = ['%sSBWP80to40' % (sSubcategory)]

eventYields = OD()
sEventYield = "%s \n" % (sIpFile)
MCBkg_total = 0
MCSig_total = 0
for selectionTag in selectionTags:   
    for systematics_name in systematics_list:
        sEventYield += "Selection: %s,  systematics: %s \n" % (selectionTag, systematics_name)
        sEventYield += "%-45s:  %15s +- %15s  (%15s) \n" % ('Samples', 'nEvents', 'Uncertainty', 'nEvents_unweighted')
        eventYields[systematics_name] = OD()
        MCBkg_total = 0;   MCBkg_total_variance = 0
        MCSig_total = 0;   MCSig_total_variance = 0
        Data_total  = 0;   Data_total_variance  = 0

        for sData, ExpData_list in ExpData_dict.items():
            for sample_category in MCSig_list + MCBkg_list + ExpData_list:
                # "hCutFlowWeighted"
                systematics_name_toUse = systematics_name if sample_category not in ExpData_list else systematics_forData

                histo_name_full = 'evt/%s/%s_%s_%s' % (sample_category, "hCutFlowWeighted", selectionTag, systematics_name_toUse)
                #print(f"{histo_name_full = }")
                h = fIpFile[histo_name_full].to_hist()
                nEvt_and_var = getTH1BinContent(h, xValue=xValueForEventYield)

                #histo_name_full = 'evt/%s/%s_%s' % (sample_category, "hCutFlow", systematics_name_toUse)
                histo_name_full = 'evt/%s/%s_%s_%s' % (sample_category, "hCutFlow", selectionTag, systematics_name_toUse)
                h = fIpFile[histo_name_full].to_hist()
                nEvt_and_var_unwgt = getTH1BinContent(h, xValue=xValueForEventYield)

                if sample_category in MCBkg_list:      
                    MCBkg_total          += nEvt_and_var.value
                    MCBkg_total_variance += nEvt_and_var.variance 

                if sample_category in MCSig_list:      
                    MCSig_total          += nEvt_and_var.value
                    MCSig_total_variance += nEvt_and_var.variance

                if sample_category in ExpData_list:    
                    Data_total  += nEvt_and_var.value
                    Data_total_variance  += nEvt_and_var.variance

                #print(f"{sample_category = },  \t\t\t\t\t nEvents: {nEvt_and_var.value}, \t\t  {np.sqrt(nEvt_and_var.variance)}")
                #print("%-45s:  %15g +- %15g  (%15d)" % (sample_category, nEvt_and_var.value, np.sqrt(nEvt_and_var.variance), nEvt_and_var_unwgt.value))
                sEventYield += "%-45s:  %15g +- %15g  (%15d) \n" % (sample_category, nEvt_and_var.value, np.sqrt(nEvt_and_var.variance), nEvt_and_var_unwgt.value)


                eventYields[systematics_name][sample_category] = OD([
                    ('nEvents', nEvt_and_var.value),
                    ('Uncertainty', np.sqrt(nEvt_and_var.variance)),
                    ('nEventsUnwgt', nEvt_and_var_unwgt.value),
                    ('isMCBkg', sample_category in MCBkg_list)
                    ])  
            
        sEventYield += "\n"
        sEventYield += "%-45s:  %15g +- %15g  \n" % ('Data_total', Data_total, np.sqrt(Data_total_variance))
        sEventYield += "%-45s:  %15g +- %15g  \n" % ('Bkg_total', MCBkg_total, np.sqrt(MCSig_total_variance))
        sEventYield += "%-45s:  %15g  \n" % ('Data/MCBkg', Data_total / MCBkg_total if MCBkg_total > 0 else 0)
        for idx_, sample_category in enumerate(MCSig_list):
            if abs(MCBkg_total - 0) < 1e-6: continue
            sEventYield += "%-45s:  %15g  \n" % ('S/sqrt(B) @ %s' % (sLableSig[idx_]), eventYields[systematics_name][sample_category]['nEvents'] / np.sqrt(MCBkg_total))
        sEventYield += "\n\n" 


        ## print sorted event yield table
        #bkgs_list = list(eventYields[systematics_name].keys())
        bkgs_list = [ process for process in eventYields[systematics_name].keys() if eventYields[systematics_name][process]['isMCBkg']  ]
        nEvent_bkgs_list = [ eventYields[systematics_name][bkg]['nEvents'] for bkg in bkgs_list]
        bkgRanks  = np.argsort(np.array(nEvent_bkgs_list))[::-1]
        print(f"{bkgs_list = }")
        print(f"{nEvent_bkgs_list = }")
        print(f"{np.argsort(np.array(nEvent_bkgs_list)) = }")
        print(f"{bkgRanks = }")

        sEventYield += "Sorted background processes::\n"
        for bkgRank in bkgRanks:
            processName_ = bkgs_list[bkgRank]
            sEventYield += "%-45s:  %15g +- %15g  (%15d) \n" % (
                processName_, 
                eventYields[systematics_name][processName_]['nEvents'],
                eventYields[systematics_name][processName_]['Uncertainty'],
                eventYields[systematics_name][processName_]['nEventsUnwgt'])
        sEventYield += "\n\n" 

        

print("%s" % (sEventYield))
#print(f"{json.dumps(eventYields, indent=4) = }")
#json.dumps(eventYields, indent=4)

with open('%s/eventYieldTable.txt' % (sOpDir), 'w') as fOut:
    fOut.write(sEventYield)
# Out:
# bkgs_list = ['QCD_bEnr', 'QCD_BGen', 'QCD_Incl', 'TT0l', 'TT1l', 'TT2l', 'STop_t', 'STbar_t', 'ST_s_0l', 'ST_s_1l', 'STop_tW_Incl', 'STbar_tW_Incl', 'STop_tW_12l', 'STbar_tW_12l', 'Zqq', 'Zvv', 'Zll', 'Wqq', 'Wlv', 'ZZ', 'WZ', 'WW']
# nEvent_bkgs_list = [2100.0838696539113, 3127.214735225681, 18.43957495141764, 3.8750801920816027, 3.958717890846404, 0.5709844039762478, 0.6009693667826301, 0.38474734073765626, 0.05463045756063884, 0.10176642832146515, 0.552151884188889, 0.2681987400935511, 0.0, 0.18070737517004476, 55.73962363572597, 0.06888819371622305, 0.0, 0.0, 3.1007054253048847, 1.5586055891884933, 0.8051601041700084, 0.0]
# np.argsort(np.array(nEvent_bkgs_list)) = array([21, 17, 16, 12,  8, 15,  9, 13, 11,  7, 10,  5,  6, 20, 19, 18,  3,
#         4,  2, 14,  0,  1])
# bkgRanks = array([ 1,  0, 14,  2,  4,  3, 18, 19, 20,  6,  5, 10,  7, 11, 13,  9, 15,
#         8, 12, 16, 17, 21])
# bkgs_list = ['QCD_bEnr', 'QCD_BGen', 'QCD_Incl', 'TT0l', 'TT1l', 'TT2l', 'STop_t', 'STbar_t', 'ST_s_0l', 'ST_s_1l', 'STop_tW_Incl', 'STbar_tW_Incl', 'STop_tW_12l', 'STbar_tW_12l', 'Zqq', 'Zvv', 'Zll', 'Wqq', 'Wlv', 'ZZ', 'WZ', 'WW']
# nEvent_bkgs_list = [23223.64532461692, 36294.485562227055, 661.5168401403943, 190.0440726934698, 102.99715391693533, 11.755962125698703, 10.884601849241447, 4.522008186614287, 1.4476882128952837, 1.2172167443186865, 10.591885644170308, 9.47693179000786, 2.5515853436865217, 2.756043408167768, 531.1837622736102, 1.4811957770679423, 3.449118560465098, 8.637446052339211, 48.07549386092028, 6.571132048352293, 8.322171288251429, 2.2332732318266317]
# np.argsort(np.array(nEvent_bkgs_list)) = array([ 9,  8, 15, 21, 12, 13, 16,  7, 19, 20, 17, 11, 10,  6,  5, 18,  4,
#         3, 14,  2,  0,  1])
# bkgRanks = array([ 1,  0,  2, 14,  3,  4, 18,  5,  6, 10, 11, 17, 20, 19,  7, 16, 13,
#        12, 21, 15,  8,  9])
# /eos/cms/store/user/ssawant/htoaa/analysis/20250507_gg0l_DataMCPlots_NoSyst/2018/analyze_htoaa_stage1.root
# Selection: gg0lIncl_Xto4bv2_SRWP40,  systematics: Nom
# Samples                                      :          nEvents +-     Uncertainty  (nEvents_unweighted)
# ggHtoaato4b_mA_15                            :          2236.47 +-          20.276  (          17296)
# ggHtoaato4b_mA_30                            :           1261.9 +-         15.5907  (          10053)
# QCD_bEnr                                     :          2100.08 +-         130.834  (            777)
# QCD_BGen                                     :          3127.21 +-         212.577  (            662)
# QCD_Incl                                     :          18.4396 +-         12.3457  (              5)
# TT0l                                         :          3.87508 +-        0.521869  (             61)
# TT1l                                         :          3.95872 +-        0.428298  (             88)
# TT2l                                         :         0.570984 +-        0.143246  (             16)
# STop_t                                       :         0.600969 +-        0.161295  (             14)
# STbar_t                                      :         0.384747 +-        0.146785  (              7)
# ST_s_0l                                      :        0.0546305 +-       0.0386364  (              2)
# ST_s_1l                                      :         0.101766 +-       0.0512092  (              4)
# STop_tW_Incl                                 :         0.552152 +-        0.390689  (              2)
# STbar_tW_Incl                                :         0.268199 +-        0.268199  (              1)
# STop_tW_12l                                  :                0 +-               0  (              0)
# STbar_tW_12l                                 :         0.180707 +-        0.138198  (              2)
# Zqq                                          :          55.7396 +-         2.64689  (            559)
# Zvv                                          :        0.0688882 +-       0.0487121  (              2)
# Zll                                          :                0 +-               0  (              0)
# Wqq                                          :                0 +-               0  (              0)
# Wlv                                          :          3.10071 +-        0.426868  (            109)
# ZZ                                           :          1.55861 +-        0.702368  (              5)
# WZ                                           :          0.80516 +-        0.505209  (              3)
# WW                                           :                0 +-               0  (              0)
# JetHT_Run2018A                               :              921 +-          30.348  (            921)
# JetHT_Run2018B                               :              588 +-         24.2487  (            588)
# JetHT_Run2018C                               :              560 +-         23.6643  (            560)
# JetHT_Run2018D                               :             2352 +-         48.4974  (           2352)
#
# Data_total                                   :             4421 +-         66.4906
# Bkg_total                                    :          5317.56 +-         25.5771
# Data/MCBkg                                   :         0.831396
# S/sqrt(B) @ ggHtoaato4b_mA_15                :          30.6695
# S/sqrt(B) @ ggHtoaato4b_mA_30                :          17.3048
#
#
# Sorted background processes::
# QCD_BGen                                     :          3127.21 +-         212.577  (            662)
# QCD_bEnr                                     :          2100.08 +-         130.834  (            777)
# Zqq                                          :          55.7396 +-         2.64689  (            559)
# QCD_Incl                                     :          18.4396 +-         12.3457  (              5)
# TT1l                                         :          3.95872 +-        0.428298  (             88)
# TT0l                                         :          3.87508 +-        0.521869  (             61)
# Wlv                                          :          3.10071 +-        0.426868  (            109)
# ZZ                                           :          1.55861 +-        0.702368  (              5)
# WZ                                           :          0.80516 +-        0.505209  (              3)
# STop_t                                       :         0.600969 +-        0.161295  (             14)
# TT2l                                         :         0.570984 +-        0.143246  (             16)
# STop_tW_Incl                                 :         0.552152 +-        0.390689  (              2)
# STbar_t                                      :         0.384747 +-        0.146785  (              7)
# STbar_tW_Incl                                :         0.268199 +-        0.268199  (              1)
# STbar_tW_12l                                 :         0.180707 +-        0.138198  (              2)
# ST_s_1l                                      :         0.101766 +-       0.0512092  (              4)
# Zvv                                          :        0.0688882 +-       0.0487121  (              2)
# ST_s_0l                                      :        0.0546305 +-       0.0386364  (              2)
# STop_tW_12l                                  :                0 +-               0  (              0)
# Zll                                          :                0 +-               0  (              0)
# Wqq                                          :                0 +-               0  (              0)
# WW                                           :                0 +-               0  (              0)
#
#
# Selection: gg0lIncl_Xto4bv2_SBWP40,  systematics: Nom
# Samples                                      :          nEvents +-     Uncertainty  (nEvents_unweighted)
# ggHtoaato4b_mA_15                            :          863.014 +-         13.0755  (           6181)
# ggHtoaato4b_mA_30                            :          1281.85 +-         16.3647  (           9254)
# QCD_bEnr                                     :          23223.6 +-         474.543  (           8087)
# QCD_BGen                                     :          36294.5 +-          641.84  (           7286)
# QCD_Incl                                     :          661.517 +-         79.9288  (            180)
# TT0l                                         :          190.044 +-         3.58425  (           2960)
# TT1l                                         :          102.997 +-         2.16609  (           2336)
# TT2l                                         :           11.756 +-        0.644658  (            338)
# STop_t                                       :          10.8846 +-        0.681138  (            263)
# STbar_t                                      :          4.52201 +-        0.474139  (             93)
# ST_s_0l                                      :          1.44769 +-        0.247892  (             68)
# ST_s_1l                                      :          1.21722 +-         0.17049  (             52)
# STop_tW_Incl                                 :          10.5919 +-         1.82439  (             34)
# STbar_tW_Incl                                :          9.47693 +-         1.78093  (             29)
# STop_tW_12l                                  :          2.55159 +-         0.54517  (             22)
# STbar_tW_12l                                 :          2.75604 +-        0.576578  (             23)
# Zqq                                          :          531.184 +-         8.23765  (           5324)
# Zvv                                          :           1.4812 +-        0.226126  (             44)
# Zll                                          :          3.44912 +-         3.44912  (              1)
# Wqq                                          :          8.63745 +-         3.86648  (              5)
# Wlv                                          :          48.0755 +-         2.29104  (           1332)
# ZZ                                           :          6.57113 +-         1.35522  (             24)
# WZ                                           :          8.32217 +-         1.70327  (             26)
# WW                                           :          2.23327 +-        0.998956  (              5)
# JetHT_Run2018A                               :            15280 +-         123.612  (          15280)
# JetHT_Run2018B                               :             9219 +-         96.0156  (           9219)
# JetHT_Run2018C                               :             8305 +-         91.1318  (           8305)
# JetHT_Run2018D                               :            39728 +-         199.319  (          39728)
#
# Data_total                                   :            72532 +-         269.318
# Bkg_total                                    :          61137.8 +-         20.9469
# Data/MCBkg                                   :          1.18637
# S/sqrt(B) @ ggHtoaato4b_mA_15                :           3.4903
# S/sqrt(B) @ ggHtoaato4b_mA_30                :           5.1842
#
#
# Sorted background processes::
# QCD_BGen                                     :          36294.5 +-          641.84  (           7286)
# QCD_bEnr                                     :          23223.6 +-         474.543  (           8087)
# QCD_Incl                                     :          661.517 +-         79.9288  (            180)
# Zqq                                          :          531.184 +-         8.23765  (           5324)
# TT0l                                         :          190.044 +-         3.58425  (           2960)
# TT1l                                         :          102.997 +-         2.16609  (           2336)
# Wlv                                          :          48.0755 +-         2.29104  (           1332)
# TT2l                                         :           11.756 +-        0.644658  (            338)
# STop_t                                       :          10.8846 +-        0.681138  (            263)
# STop_tW_Incl                                 :          10.5919 +-         1.82439  (             34)
# STbar_tW_Incl                                :          9.47693 +-         1.78093  (             29)
# Wqq                                          :          8.63745 +-         3.86648  (              5)
# WZ                                           :          8.32217 +-         1.70327  (             26)
# ZZ                                           :          6.57113 +-         1.35522  (             24)
# STbar_t                                      :          4.52201 +-        0.474139  (             93)
# Zll                                          :          3.44912 +-         3.44912  (              1)
# STbar_tW_12l                                 :          2.75604 +-        0.576578  (             23)
# STop_tW_12l                                  :          2.55159 +-         0.54517  (             22)
# WW                                           :          2.23327 +-        0.998956  (              5)
# Zvv                                          :           1.4812 +-        0.226126  (             44)
# ST_s_0l                                      :          1.44769 +-        0.247892  (             68)
# ST_s_1l                                      :          1.21722 +-         0.17049  (             52)
